# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAlYousif-AI/O0Zdp1U9TiVA1Qvv/blob/main/Potential%20Talents%20Project%20(FastText).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the Essential libraries and their Functions

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import nltk
import re

# %%
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("/content/potential-talents.csv")

data
# Out:
#       id                                          job_title  \
# 0    1.0  2019 C.T. Bauer College of Business Graduate (...
# 1    2.0  Native English Teacher at EPIK (English Progra...
# 2    3.0              Aspiring Human Resources Professional
# 3    4.0             People Development Coordinator at Ryan
# 4    5.0    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 994  NaN                                                NaN
# 995  NaN                                                NaN
# 996  NaN                                                NaN
# 997  NaN                                                NaN
# 998  NaN                                                NaN
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# 3                          Denton, Texas      500+   NaN
# 4                         İzmir, Türkiye      500+   NaN
# ..                                   ...        ...  ...
# 994                                  NaN        NaN  NaN
# 995                                  NaN        NaN  NaN
# 996                                  NaN        NaN  NaN
# 997                                  NaN        NaN  NaN
# 998                                  NaN        NaN  NaN
#
# [999 rows x 5 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# #EDA

# %%
data.head(20)
# Out:
#       id                                          job_title  \
# 0    1.0  2019 C.T. Bauer College of Business Graduate (...
# 1    2.0  Native English Teacher at EPIK (English Progra...
# 2    3.0              Aspiring Human Resources Professional
# 3    4.0             People Development Coordinator at Ryan
# 4    5.0    Advisory Board Member at Celal Bayar University
# 5    6.0                Aspiring Human Resources Specialist
# 6    7.0  Student at Humber College and Aspiring Human R...
# 7    8.0                               HR Senior Specialist
# 8    9.0  Student at Humber College and Aspiring Human R...
# 9   10.0  Seeking Human Resources HRIS and Generalist Po...
# 10  11.0                      Student at Chapman University
# 11  12.0  SVP, CHRO, Marketing & Communications, CSR Off...
# 12  13.0  Human Resources Coordinator at InterContinenta...
# 13  14.0  2019 C.T. Bauer College of Business Graduate (...
# 14  15.0  2019 C.T. Bauer College of Business Graduate (...
# 15  16.0  Native English Teacher at EPIK (English Progra...
# 16  17.0              Aspiring Human Resources Professional
# 17  18.0             People Development Coordinator at Ryan
# 18  19.0  2019 C.T. Bauer College of Business Graduate (...
# 19  20.0  Native English Teacher at EPIK (English Progra...
#
#                                location connection  fit
# 0                        Houston, Texas         85  NaN
# 1                                Kanada      500+   NaN
# 2   Raleigh-Durham, North Carolina Area         44  NaN
# 3                         Denton, Texas      500+   NaN
# 4                        İzmir, Türkiye      500+   NaN
# 5            Greater New York City Area          1  NaN
# 6                                Kanada         61  NaN
# 7                San Francisco Bay Area      500+   NaN
# 8                                Kanada         61  NaN
# 9             Greater Philadelphia Area      500+   NaN
# 10              Lake Forest, California          2  NaN
# 11                  Houston, Texas Area      500+   NaN
# 12                     Atlanta, Georgia      500+   NaN
# 13                       Houston, Texas         85  NaN
# 14                       Houston, Texas         85  NaN
# 15                               Kanada      500+   NaN
# 16  Raleigh-Durham, North Carolina Area         44  NaN
# 17                        Denton, Texas      500+   NaN
# 18                       Houston, Texas         85  NaN
# 19                               Kanada      500+   NaN

# %%
data.tail(20)
# Out:
#      id job_title location connection  fit
# 979 NaN       NaN      NaN        NaN  NaN
# 980 NaN       NaN      NaN        NaN  NaN
# 981 NaN       NaN      NaN        NaN  NaN
# 982 NaN       NaN      NaN        NaN  NaN
# 983 NaN       NaN      NaN        NaN  NaN
# 984 NaN       NaN      NaN        NaN  NaN
# 985 NaN       NaN      NaN        NaN  NaN
# 986 NaN       NaN      NaN        NaN  NaN
# 987 NaN       NaN      NaN        NaN  NaN
# 988 NaN       NaN      NaN        NaN  NaN
# 989 NaN       NaN      NaN        NaN  NaN
# 990 NaN       NaN      NaN        NaN  NaN
# 991 NaN       NaN      NaN        NaN  NaN
# 992 NaN       NaN      NaN        NaN  NaN
# 993 NaN       NaN      NaN        NaN  NaN
# 994 NaN       NaN      NaN        NaN  NaN
# 995 NaN       NaN      NaN        NaN  NaN
# 996 NaN       NaN      NaN        NaN  NaN
# 997 NaN       NaN      NaN        NaN  NaN
# 998 NaN       NaN      NaN        NaN  NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          104 non-null    float64
#  1   job_title   104 non-null    object
#  2   location    104 non-null    object
#  3   connection  104 non-null    object
#  4   fit         0 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 39.2+ KB

# %%
data.isnull()
# Out:
#         id  job_title  location  connection   fit
# 0    False      False     False       False  True
# 1    False      False     False       False  True
# 2    False      False     False       False  True
# 3    False      False     False       False  True
# 4    False      False     False       False  True
# ..     ...        ...       ...         ...   ...
# 994   True       True      True        True  True
# 995   True       True      True        True  True
# 996   True       True      True        True  True
# 997   True       True      True        True  True
# 998   True       True      True        True  True
#
# [999 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# id            895
# job_title     895
# location      895
# connection    895
# fit           999
# dtype: int64

# %%
data.describe()
# Out:
#                id  fit
# count  104.000000  0.0
# mean    52.500000  NaN
# std     30.166206  NaN
# min      1.000000  NaN
# 25%     26.750000  NaN
# 50%     52.500000  NaN
# 75%     78.250000  NaN
# max    104.000000  NaN

# %%
data.count()
# Out:
# id            104
# job_title     104
# location      104
# connection    104
# fit             0
# dtype: int64

# %%
data.dtypes.value_counts()
# Out:
# object     3
# float64    2
# Name: count, dtype: int64

# %%
data.drop(['id'], axis=1, inplace=True)

data
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# 3                          Denton, Texas      500+   NaN
# 4                         İzmir, Türkiye      500+   NaN
# ..                                   ...        ...  ...
# 994                                  NaN        NaN  NaN
# 995                                  NaN        NaN  NaN
# 996                                  NaN        NaN  NaN
# 997                                  NaN        NaN  NaN
# 998                                  NaN        NaN  NaN
#
# [999 rows x 4 columns]

# %% [markdown]
# #Removing the Missing Values

# %%
data_2 = data.copy()

data_2
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# 3                          Denton, Texas      500+   NaN
# 4                         İzmir, Türkiye      500+   NaN
# ..                                   ...        ...  ...
# 994                                  NaN        NaN  NaN
# 995                                  NaN        NaN  NaN
# 996                                  NaN        NaN  NaN
# 997                                  NaN        NaN  NaN
# 998                                  NaN        NaN  NaN
#
# [999 rows x 4 columns]

# %%
data_2.drop(['fit'], axis=1, inplace=True)

# %%
data_2.dropna(subset=['job_title'], inplace=True)

data_2
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                 location connection
# 0                         Houston, Texas         85
# 1                                 Kanada      500+
# 2    Raleigh-Durham, North Carolina Area         44
# 3                          Denton, Texas      500+
# 4                         İzmir, Türkiye      500+
# ..                                   ...        ...
# 99              Cape Girardeau, Missouri        103
# 100  Raleigh-Durham, North Carolina Area      500+
# 101           Greater New York City Area         49
# 102             Greater Los Angeles Area      500+
# 103                          Katy, Texas      500+
#
# [104 rows x 3 columns]

# %%
data_2.isnull().sum()
# Out:
# job_title     0
# location      0
# connection    0
# dtype: int64

# %%
data_2.head()
# Out:
#                                            job_title  \
# 0  2019 C.T. Bauer College of Business Graduate (...
# 1  Native English Teacher at EPIK (English Progra...
# 2              Aspiring Human Resources Professional
# 3             People Development Coordinator at Ryan
# 4    Advisory Board Member at Celal Bayar University
#
#                               location connection
# 0                       Houston, Texas         85
# 1                               Kanada      500+
# 2  Raleigh-Durham, North Carolina Area         44
# 3                        Denton, Texas      500+
# 4                       İzmir, Türkiye      500+

# %%
data_2.tail()
# Out:
#                                              job_title  \
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                 location connection
# 99              Cape Girardeau, Missouri        103
# 100  Raleigh-Durham, North Carolina Area      500+
# 101           Greater New York City Area         49
# 102             Greater Los Angeles Area      500+
# 103                          Katy, Texas      500+

# %%
data_2.drop(['location'], axis=1, inplace=True)

data_2
# Out:
#                                              job_title connection
# 0    2019 C.T. Bauer College of Business Graduate (...         85
# 1    Native English Teacher at EPIK (English Progra...      500+
# 2                Aspiring Human Resources Professional         44
# 3               People Development Coordinator at Ryan      500+
# 4      Advisory Board Member at Celal Bayar University      500+
# ..                                                 ...        ...
# 99   Aspiring Human Resources Manager | Graduating ...        103
# 100              Human Resources Generalist at Loparex      500+
# 101   Business Intelligence and Analytics at Travelers         49
# 102                     Always set them up for Success      500+
# 103   Director Of Administration at Excellence Logging      500+
#
# [104 rows x 2 columns]

# %%
data_2['connection'].unique()
# Out:
# array(['85', '500+ ', '44', '1', '61', '2', '390', '57', '82', '5', '7',
#        '16', '212', '409', '52', '455', '174', '268', '50', '4', '40',
#        '18', '349', '155', '39', '64', '9', '415', '19', '71', '48',
#        '103', '49'], dtype=object)

# %%
# !pip install fasttext
# Out:
# Requirement already satisfied: fasttext in /usr/local/lib/python3.11/dist-packages (0.9.3)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.11/dist-packages (from fasttext) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from fasttext) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fasttext) (2.0.2)

# %%
from huggingface_hub import hf_hub_download
import fasttext
nltk.download('punkt_tab')

fasttext_model = fasttext.load_model(hf_hub_download("facebook/fasttext-en-vectors", "model.bin"))

# Function to clean and tokenize text
def preprocess_text(text):
    text = text.lower()  # Lowercasing
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Remove special characters
    tokens = word_tokenize(text)  # Tokenization
    return [word for word in tokens if word in fasttext_model]  # Keep only known words

# Function to get sentence vector by averaging word vectors
def sentence_to_vector(sentence, model):
    words = preprocess_text(sentence)
    if not words:
        return np.zeros(model.vector_size)  # Return zero vector if no valid words
    return np.mean([model[word] for word in words], axis=0)

# Apply FastText to each sentence in the column
data_2['job_title_embedding'] = data_2['job_title'].apply(lambda x: sentence_to_vector(x, fasttext_model))

# Display results
print(data_2[['job_title', 'job_title_embedding']])
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...
# ..                                                 ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...
#
# [104 rows x 2 columns]

# %%
w1 = sentence_to_vector('Aspiring human resources', fasttext_model)

# %%
data_2['cosine_similarity'] = data_2['job_title_embedding'].apply(lambda x: cosine_similarity([w1], [x])[0][0])

data_2['cosine_similarity']
# Out:
# 0      0.395398
# 1      0.253072
# 2      0.982771
# 3      0.180921
# 4      0.164732
#          ...
# 99     0.500876
# 100    0.410244
# 101    0.268428
# 102    0.257655
# 103    0.233593
# Name: cosine_similarity, Length: 104, dtype: float32

# %%
data_2
# Out:
#                                              job_title connection  \
# 0    2019 C.T. Bauer College of Business Graduate (...         85
# 1    Native English Teacher at EPIK (English Progra...      500+
# 2                Aspiring Human Resources Professional         44
# 3               People Development Coordinator at Ryan      500+
# 4      Advisory Board Member at Celal Bayar University      500+
# ..                                                 ...        ...
# 99   Aspiring Human Resources Manager | Graduating ...        103
# 100              Human Resources Generalist at Loparex      500+
# 101   Business Intelligence and Analytics at Travelers         49
# 102                     Always set them up for Success      500+
# 103   Director Of Administration at Excellence Logging      500+
#
#                                    job_title_embedding  cosine_similarity
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
# [104 rows x 4 columns]

# %% [markdown]
# #Labeling

# %%
data_2 = data_2[['job_title', 'job_title_embedding', 'cosine_similarity', 'connection']]

data_2
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity  \
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
#     connection
# 0           85
# 1        500+
# 2           44
# 3        500+
# 4        500+
# ..         ...
# 99         103
# 100      500+
# 101         49
# 102      500+
# 103      500+
#
# [104 rows x 4 columns]

# %%
data_3 = data_2.copy()

# %% [markdown]
# #Converting ('500+ ') to (500) for Connection Column

# %%
data_3['connection'] = data_2['connection'].replace(['500+ '], [500], inplace=True)

data_3['connection']
# Out:
# <ipython-input-28-6c6aa7968bff>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_3['connection'] = data_2['connection'].replace(['500+ '], [500], inplace=True)
# <ipython-input-28-6c6aa7968bff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_3['connection'] = data_2['connection'].replace(['500+ '], [500], inplace=True)
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 99     None
# 100    None
# 101    None
# 102    None
# 103    None
# Name: connection, Length: 104, dtype: object

# %%
data_2['connection'] = data_2['connection'].astype(int)

data_2['connection']
# Out:
# 0       85
# 1      500
# 2       44
# 3      500
# 4      500
#       ...
# 99     103
# 100    500
# 101     49
# 102    500
# 103    500
# Name: connection, Length: 104, dtype: int64

# %%
data_2['connection'].unique()
# Out:
# array([ 85, 500,  44,   1,  61,   2, 390,  57,  82,   5,   7,  16, 212,
#        409,  52, 455, 174, 268,  50,   4,  40,  18, 349, 155,  39,  64,
#          9, 415,  19,  71,  48, 103,  49])

# %%
data_2
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity  \
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
#      connection
# 0            85
# 1           500
# 2            44
# 3           500
# 4           500
# ..          ...
# 99          103
# 100         500
# 101          49
# 102         500
# 103         500
#
# [104 rows x 4 columns]

# %%
ranked_data = data_2.copy()

ranked_data
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity  \
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
#      connection
# 0            85
# 1           500
# 2            44
# 3           500
# 4           500
# ..          ...
# 99          103
# 100         500
# 101          49
# 102         500
# 103         500
#
# [104 rows x 4 columns]

# %% [markdown]
# #Feature Scaling

# %%
ranked_data.drop(['job_title', 'job_title_embedding', 'cosine_similarity'], axis=1, inplace=True)

ranked_data
# Out:
#      connection
# 0            85
# 1           500
# 2            44
# 3           500
# 4           500
# ..          ...
# 99          103
# 100         500
# 101          49
# 102         500
# 103         500
#
# [104 rows x 1 columns]

# %%
scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(ranked_data)
ranked_data['scaled_connection'] = pd.DataFrame(scaled_data, columns=ranked_data.columns)

ranked_data['scaled_connection']
# Out:
# 0      0.168337
# 1      1.000000
# 2      0.086172
# 3      1.000000
# 4      1.000000
#          ...
# 99     0.204409
# 100    1.000000
# 101    0.096192
# 102    1.000000
# 103    1.000000
# Name: scaled_connection, Length: 104, dtype: float64

# %%
ranked_data
# Out:
#      connection  scaled_connection
# 0            85           0.168337
# 1           500           1.000000
# 2            44           0.086172
# 3           500           1.000000
# 4           500           1.000000
# ..          ...                ...
# 99          103           0.204409
# 100         500           1.000000
# 101          49           0.096192
# 102         500           1.000000
# 103         500           1.000000
#
# [104 rows x 2 columns]

# %%
ranked_data[['job_title', 'job_title_embedding', 'cosine_similarity']] = data_2[['job_title', 'job_title_embedding', 'cosine_similarity']]

ranked_data
# Out:
#      connection  scaled_connection  \
# 0            85           0.168337
# 1           500           1.000000
# 2            44           0.086172
# 3           500           1.000000
# 4           500           1.000000
# ..          ...                ...
# 99          103           0.204409
# 100         500           1.000000
# 101          49           0.096192
# 102         500           1.000000
# 103         500           1.000000
#
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
# [104 rows x 5 columns]

# %%
ranked_data.drop(['connection'], axis=1, inplace=True)

ranked_data
# Out:
#      scaled_connection                                          job_title  \
# 0             0.168337  2019 C.T. Bauer College of Business Graduate (...
# 1             1.000000  Native English Teacher at EPIK (English Progra...
# 2             0.086172              Aspiring Human Resources Professional
# 3             1.000000             People Development Coordinator at Ryan
# 4             1.000000    Advisory Board Member at Celal Bayar University
# ..                 ...                                                ...
# 99            0.204409  Aspiring Human Resources Manager | Graduating ...
# 100           1.000000              Human Resources Generalist at Loparex
# 101           0.096192   Business Intelligence and Analytics at Travelers
# 102           1.000000                     Always set them up for Success
# 103           1.000000   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
# [104 rows x 4 columns]

# %%
ranked_data
# Out:
#      scaled_connection                                          job_title  \
# 0             0.168337  2019 C.T. Bauer College of Business Graduate (...
# 1             1.000000  Native English Teacher at EPIK (English Progra...
# 2             0.086172              Aspiring Human Resources Professional
# 3             1.000000             People Development Coordinator at Ryan
# 4             1.000000    Advisory Board Member at Celal Bayar University
# ..                 ...                                                ...
# 99            0.204409  Aspiring Human Resources Manager | Graduating ...
# 100           1.000000              Human Resources Generalist at Loparex
# 101           0.096192   Business Intelligence and Analytics at Travelers
# 102           1.000000                     Always set them up for Success
# 103           1.000000   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
# [104 rows x 4 columns]

# %%
ranked_data = ranked_data[['job_title', 'job_title_embedding', 'cosine_similarity', 'scaled_connection']]

ranked_data
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity  \
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
#      scaled_connection
# 0             0.168337
# 1             1.000000
# 2             0.086172
# 3             1.000000
# 4             1.000000
# ..                 ...
# 99            0.204409
# 100           1.000000
# 101           0.096192
# 102           1.000000
# 103           1.000000
#
# [104 rows x 4 columns]

# %% [markdown]
# #Ranking

# %%
ranked_data['ranking'] = 0.75 * ranked_data['cosine_similarity'] + 0.25 * ranked_data['scaled_connection']

ranked_data['ranking']
# Out:
# <ipython-input-40-d423ed477ec4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranked_data['ranking'] = 0.75 * ranked_data['cosine_similarity'] + 0.25 * ranked_data['scaled_connection']
# 0      0.338633
# 1      0.439804
# 2      0.758622
# 3      0.385690
# 4      0.373549
#          ...
# 99     0.426759
# 100    0.557683
# 101    0.225369
# 102    0.443241
# 103    0.425195
# Name: ranking, Length: 104, dtype: float64

# %%
ranked_data
# Out:
#                                              job_title  \
# 0    2019 C.T. Bauer College of Business Graduate (...
# 1    Native English Teacher at EPIK (English Progra...
# 2                Aspiring Human Resources Professional
# 3               People Development Coordinator at Ryan
# 4      Advisory Board Member at Celal Bayar University
# ..                                                 ...
# 99   Aspiring Human Resources Manager | Graduating ...
# 100              Human Resources Generalist at Loparex
# 101   Business Intelligence and Analytics at Travelers
# 102                     Always set them up for Success
# 103   Director Of Administration at Excellence Logging
#
#                                    job_title_embedding  cosine_similarity  \
# 0    [0.0152725605, -0.022511747, -0.024433596, 0.0...           0.395398
# 1    [0.024544511, 0.0061443807, -0.02365049, -0.00...           0.253072
# 2    [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 3    [0.042334706, 0.05361083, 0.033050507, -0.0071...           0.180921
# 4    [0.06376933, 0.061760258, 0.0017473322, -0.007...           0.164732
# ..                                                 ...                ...
# 99   [0.0048759514, -0.0412865, -0.0027207024, 0.05...           0.500876
# 100  [0.06540059, 0.079081535, 0.0039790524, 0.0283...           0.410244
# 101  [0.021158433, 0.051734198, 0.0146321105, -0.01...           0.268428
# 102  [-0.0083640115, -0.17212616, 0.028542055, 0.15...           0.257655
# 103  [0.04030014, 0.030382121, 0.02194167, -0.08862...           0.233593
#
#      scaled_connection   ranking
# 0             0.168337  0.338633
# 1             1.000000  0.439804
# 2             0.086172  0.758622
# 3             1.000000  0.385690
# 4             1.000000  0.373549
# ..                 ...       ...
# 99            0.204409  0.426759
# 100           1.000000  0.557683
# 101           0.096192  0.225369
# 102           1.000000  0.443241
# 103           1.000000  0.425195
#
# [104 rows x 5 columns]

# %% [markdown]
# #Sorting (Desecending)

# %%
ranked_data = ranked_data.sort_values(by='ranking', ascending=False)

ranked_data['ranking']
# Out:
# 27    0.848887
# 29    0.848887
# 66    0.822674
# 96    0.772149
# 16    0.758622
#         ...
# 90    0.184430
# 10    0.134528
# 62    0.134528
# 40    0.134528
# 53    0.134528
# Name: ranking, Length: 104, dtype: float64

# %%
ranked_data
# Out:
#                                             job_title  \
# 27              Seeking Human Resources Opportunities
# 29              Seeking Human Resources Opportunities
# 66  Human Resources, Staffing and Recruiting Profe...
# 96              Aspiring Human Resources Professional
# 16              Aspiring Human Resources Professional
# ..                                                ...
# 90       Lead Official at Western Illinois University
# 10                      Student at Chapman University
# 62                      Student at Chapman University
# 40                      Student at Chapman University
# 53                      Student at Chapman University
#
#                                   job_title_embedding  cosine_similarity  \
# 27  [0.008069926, -0.0018737718, 0.012377604, 0.08...           0.871997
# 29  [0.008069926, -0.0018737718, 0.012377604, 0.08...           0.871997
# 66  [0.006548606, -0.02515179, -0.0031713278, 0.06...           0.763565
# 96  [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# 16  [0.017723147, -0.017749855, -0.019734647, 0.08...           0.982771
# ..                                                ...                ...
# 90  [0.022828253, 0.06405978, -0.012028996, 0.0021...           0.220523
# 10  [0.06621926, 0.09548319, -0.021614028, -0.0231...           0.178703
# 62  [0.06621926, 0.09548319, -0.021614028, -0.0231...           0.178703
# 40  [0.06621926, 0.09548319, -0.021614028, -0.0231...           0.178703
# 53  [0.06621926, 0.09548319, -0.021614028, -0.0231...           0.178703
#
#     scaled_connection   ranking
# 27           0.779559  0.848887
# 29           0.779559  0.848887
# 66           1.000000  0.822674
# 96           0.140281  0.772149
# 16           0.086172  0.758622
# ..                ...       ...
# 90           0.076152  0.184430
# 10           0.002004  0.134528
# 62           0.002004  0.134528
# 40           0.002004  0.134528
# 53           0.002004  0.134528
#
# [104 rows x 5 columns]

# %% [markdown]
# # Building the Model

# %% [markdown]
# #Ranking Models

# %%
#LambdaMart
